# %% [markdown]
# Importiamo Pyomo e GLPK

# %%
import shutil
import sys
import os.path

if not shutil.which("pyomo"):
    # !pip install -q pyomo
    assert(shutil.which("pyomo"))

if not (shutil.which("glpk") or os.path.isfile("glpk")):
    if "google.colab" in sys.modules:
        # !apt-get install -y -qq glpk-utils
    else:
        try:
            # !conda install -c conda-forge glpk 
        except:
            pass
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/giovanni/opt/anaconda3
#
#   added / updated specs:
#     - glpk
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-23.1.0               |   py39h6e9494a_0         908 KB  conda-forge
#     glpk-5.0                   |       h3cb5acd_0         1.0 MB  conda-forge
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   python_abi         conda-forge/osx-64::python_abi-3.9-2_cp39
#
# The following packages will be UPDATED:
#
#   glpk                      pkgs/main::glpk-4.65-h05f8d05_3 --> conda-forge::glpk-5.0-h3cb5acd_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.01.10~ --> conda-forge::ca-certificates-2022.12.7-h033912b_0
#   certifi            pkgs/main/osx-64::certifi-2022.12.7-p~ --> conda-forge/noarch::certifi-2022.12.7-pyhd8ed1ab_0
#   conda              pkgs/main::conda-23.1.0-py39hecd8cb5_0 --> conda-forge::conda-23.1.0-py39h6e9494a_0
#   openssl              pkgs/main::openssl-1.1.1t-hca72f7f_0 --> conda-forge::openssl-1.1.1t-hfd90126_0
#
#
# Proceed ([y]/n)? ^C
#
# CondaSystemExit:
# Operation aborted.  Exiting.

# %% [markdown]
# Vogliamo modellare il problema del Bin Packing dato un insieme di oggetti $ITEMS$, un insieme di bin identici $BINS$ e un vettore di pesi $P$
#
# $~$
#
# Modello ILP:
#
# $\min \sum_{j \in BINS} y_j $
#
# $\sum_{j \in BINS} x_{ij}=1 ~~~~~i \in ITEMS$
#
# $\sum_{i \in ITEMS} w_i x_{ij} \le y_jW ~~~~~j \in BINS$
#
# $x_{ij} \in \{0,1\} ~~~~~~ i \in ITEMS ~~, j \in BINS$
#
# $y_j \in \{0,1\} ~~~~~~ j \in BINS$

# %%
ITEMS = ['calzini','pantaloni','fiammiferi','spazzolino','mattone']

BINS = ['bin1','bin2','bin3','bin4','bin5']
W = 10
p=[7,4,1,4,4]

# %%
#PESI = {'calzini':7,'pantaloni':4,'fiammiferi':1,'spazzolino':4,'mattone':4} #utilizziamo le liste per assegnare in peso agli oggetti
PESI = dict(zip(ITEMS,p))
print (PESI)

# %% [markdown]
# Importiamo la libreria PYOMO

# %%
from pyomo.environ import * #qui andrebbe a seguire un nome che diventi quella che usiamo nel codice, best practice

# %%
BPP = ConcreteModel() #chiamo il modello mix

# %% [markdown]
# Definiamo delle variabili non negative

# %%
BPP.x = Var(ITEMS, BINS, within=Binary)
BPP.y = Var(BINS, within=Binary)

# %% [markdown]
# Definiamo la funzione obiettivo ma per farlo definiamo una funzione che prende come argomento il modello(chiamato genericamente mod, parametro informale) che poi passiamo alla funzione come rule

# %%
def obj_rule(mod):
  return sum(mod.y[j] for j in BINS)
BPP.obj = Objective(rule=obj_rule, sense = minimize) #la funzione obiettivo si aspetta o una espressione o una regola che restituisca un valore ma non prende in input un valore

# %%
def packed_rule(mod, i): #gli passo i come elemento dell'insieme ITEMS
  return sum(mod.x[i,j] for j in BINS) == 1
BPP.pack_const = Constraint(ITEMS, rule=packed_rule) #qui pyomo prende ogni elemento dell'insieme ITEMS, chiama la funzione

# %% [markdown]
# Allo stesso modo definiamo i vincoli. Innanzitutto definiamo una funzione che prende come argomento il modello (mod) e un parametro m.
#
# Attenzione: abbiamo un vincolo per ogni materiale, cioe per ogni elemento $m$ della lista $M$

# %%
def weight_rule(mod, j):
  return sum(PESI[i] * mod.x[i,j] for i in ITEMS) <= W * mod.y[j]
BPP.capacity_const = Constraint(BINS, rule=weight_rule) #qui pyomo prende ogni elemento dell'insieme ITEMS, chiama la funzione

# %%
SolverFactory('glpk').solve(BPP, tee=True)
# Out:
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /var/folders/b2/kqnx_r5555gfw4sz0bdz9b440000gp/T/tmp49jwmc8u.glpk.raw
#  --wglp /var/folders/b2/kqnx_r5555gfw4sz0bdz9b440000gp/T/tmpkng6btq3.glpk.glp
#  --cpxlp /var/folders/b2/kqnx_r5555gfw4sz0bdz9b440000gp/T/tmpelu6u1oy.pyomo.lp
# Reading problem data from '/var/folders/b2/kqnx_r5555gfw4sz0bdz9b440000gp/T/tmpelu6u1oy.pyomo.lp'...
# /var/folders/b2/kqnx_r5555gfw4sz0bdz9b440000gp/T/tmpelu6u1oy.pyomo.lp:133: warning: lower bound of variable 'x1' redefined
# /var/folders/b2/kqnx_r5555gfw4sz0bdz9b440000gp/T/tmpelu6u1oy.pyomo.lp:133: warning: upper bound of variable 'x1' redefined
# 11 rows, 31 columns, 56 non-zeros
# 30 integer variables, all of which are binary
# 163 lines were read
# Writing problem data to '/var/folders/b2/kqnx_r5555gfw4sz0bdz9b440000gp/T/tmpkng6btq3.glpk.glp'...
# 118 lines were written
# GLPK Integer Optimizer, v4.65
# 11 rows, 31 columns, 56 non-zeros
# 30 integer variables, all of which are binary
# Preprocessing...
# 10 rows, 30 columns, 55 non-zeros
# 30 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+01  ratio =  1.000e+01
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 10
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 10 rows, 30 columns, 55 non-zeros
#       0: obj =   0.000000000e+00 inf =   2.000e+01 (2)
#       8: obj =   2.000000000e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +     8: mip =     not found yet >=              -inf        (1; 0)
# +    19: >>>>>   3.000000000e+00 >=   2.000000000e+00  33.3% (7; 0)
# +    58: mip =   3.000000000e+00 >=     tree is empty   0.0% (0; 31)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.1 Mb (81126 bytes)
# Writing MIP solution to '/var/folders/b2/kqnx_r5555gfw4sz0bdz9b440000gp/T/tmp49jwmc8u.glpk.raw'...
# 51 lines were written
# {'Problem': [{'Name': 'unknown', 'Lower bound': 3.0, 'Upper bound': 3.0, 'Number of objectives': 1, 'Number of constraints': 11, 'Number of variables': 31, 'Number of nonzeros': 56, 'Sense': 'minimize'}], 'Solver': [{'Status': 'ok', 'Termination condition': 'optimal', 'Statistics': {'Branch and bound': {'Number of bounded subproblems': '31', 'Number of created subproblems': '31'}}, 'Error rc': 0, 'Time': 0.04834794998168945}], 'Solution': [OrderedDict([('number of solutions', 0), ('number of solutions displayed', 0)])]}

# %%
BPP.pprint()
# Out:
# 6 Set Declarations
#     capacity_const_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    5 : {'bin1', 'bin2', 'bin3', 'bin4', 'bin5'}
#     pack_const_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    5 : {'calzini', 'pantaloni', 'fiammiferi', 'spazzolino', 'mattone'}
#     x_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain              : Size : Members
#         None :     2 : x_index_0*x_index_1 :   25 : {('calzini', 'bin1'), ('calzini', 'bin2'), ('calzini', 'bin3'), ('calzini', 'bin4'), ('calzini', 'bin5'), ('pantaloni', 'bin1'), ('pantaloni', 'bin2'), ('pantaloni', 'bin3'), ('pantaloni', 'bin4'), ('pantaloni', 'bin5'), ('fiammiferi', 'bin1'), ('fiammiferi', 'bin2'), ('fiammiferi', 'bin3'), ('fiammiferi', 'bin4'), ('fiammiferi', 'bin5'), ('spazzolino', 'bin1'), ('spazzolino', 'bin2'), ('spazzolino', 'bin3'), ('spazzolino', 'bin4'), ('spazzolino', 'bin5'), ('mattone', 'bin1'), ('mattone', 'bin2'), ('mattone', 'bin3'), ('mattone', 'bin4'), ('mattone', 'bin5')}
#     x_index_0 : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    5 : {'calzini', 'pantaloni', 'fiammiferi', 'spazzolino', 'mattone'}
#     x_index_1 : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    5 : {'bin1', 'bin2', 'bin3', 'bin4', 'bin5'}
#     y_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    5 : {'bin1', 'bin2', 'bin3', 'bin4', 'bin5'}
#
# 2 Var Declarations
#     x : Size=25, Index=x_index
#         Key                    : Lower : Value : Upper : Fixed : Stale : Domain
#            ('calzini', 'bin1') :     0 :   0.0 :     1 : False : False : Binary
#            ('calzini', 'bin2') :     0 :   1.0 :     1 : False : False : Binary
#            ('calzini', 'bin3') :     0 :   0.0 :     1 : False : False : Binary
#            ('calzini', 'bin4') :     0 :   0.0 :     1 : False : False : Binary
#            ('calzini', 'bin5') :     0 :   0.0 :     1 : False : False : Binary
#         ('fiammiferi', 'bin1') :     0 :   0.0 :     1 : False : False : Binary
#         ('fiammiferi', 'bin2') :     0 :   1.0 :     1 : False : False : Binary
#         ('fiammiferi', 'bin3') :     0 :   0.0 :     1 : False : False : Binary
#         ('fiammiferi', 'bin4') :     0 :   0.0 :     1 : False : False : Binary
#         ('fiammiferi', 'bin5') :     0 :   0.0 :     1 : False : False : Binary
#            ('mattone', 'bin1') :     0 :   1.0 :     1 : False : False : Binary
#            ('mattone', 'bin2') :     0 :   0.0 :     1 : False : False : Binary
#            ('mattone', 'bin3') :     0 :   0.0 :     1 : False : False : Binary
#            ('mattone', 'bin4') :     0 :   0.0 :     1 : False : False : Binary
#            ('mattone', 'bin5') :     0 :   0.0 :     1 : False : False : Binary
#          ('pantaloni', 'bin1') :     0 :   0.0 :     1 : False : False : Binary
#          ('pantaloni', 'bin2') :     0 :   0.0 :     1 : False : False : Binary
#          ('pantaloni', 'bin3') :     0 :   0.0 :     1 : False : False : Binary
#          ('pantaloni', 'bin4') :     0 :   1.0 :     1 : False : False : Binary
#          ('pantaloni', 'bin5') :     0 :   0.0 :     1 : False : False : Binary
#         ('spazzolino', 'bin1') :     0 :   1.0 :     1 : False : False : Binary
#         ('spazzolino', 'bin2') :     0 :   0.0 :     1 : False : False : Binary
#         ('spazzolino', 'bin3') :     0 :   0.0 :     1 : False : False : Binary
#         ('spazzolino', 'bin4') :     0 :   0.0 :     1 : False : False : Binary
#         ('spazzolino', 'bin5') :     0 :   0.0 :     1 : False : False : Binary
#     y : Size=5, Index=y_index
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         bin1 :     0 :   1.0 :     1 : False : False : Binary
#         bin2 :     0 :   1.0 :     1 : False : False : Binary
#         bin3 :     0 :   0.0 :     1 : False : False : Binary
#         bin4 :     0 :   1.0 :     1 : False : False : Binary
#         bin5 :     0 :   0.0 :     1 : False : False : Binary
#
# 1 Objective Declarations
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : y[bin1] + y[bin2] + y[bin3] + y[bin4] + y[bin5]
#
# 2 Constraint Declarations
#     capacity_const : Size=5, Index=capacity_const_index, Active=True
#         Key  : Lower : Body                                                                                                                 : Upper : Active
#         bin1 :  -Inf : 7*x[calzini,bin1] + 4*x[pantaloni,bin1] + x[fiammiferi,bin1] + 4*x[spazzolino,bin1] + 4*x[mattone,bin1] - 10*y[bin1] :   0.0 :   True
#         bin2 :  -Inf : 7*x[calzini,bin2] + 4*x[pantaloni,bin2] + x[fiammiferi,bin2] + 4*x[spazzolino,bin2] + 4*x[mattone,bin2] - 10*y[bin2] :   0.0 :   True
#         bin3 :  -Inf : 7*x[calzini,bin3] + 4*x[pantaloni,bin3] + x[fiammiferi,bin3] + 4*x[spazzolino,bin3] + 4*x[mattone,bin3] - 10*y[bin3] :   0.0 :   True
#         bin4 :  -Inf : 7*x[calzini,bin4] + 4*x[pantaloni,bin4] + x[fiammiferi,bin4] + 4*x[spazzolino,bin4] + 4*x[mattone,bin4] - 10*y[bin4] :   0.0 :   True
#         bin5 :  -Inf : 7*x[calzini,bin5] + 4*x[pantaloni,bin5] + x[fiammiferi,bin5] + 4*x[spazzolino,bin5] + 4*x[mattone,bin5] - 10*y[bin5] :   0.0 :   True
#     pack_const : Size=5, Index=pack_const_index, Active=True
#         Key        : Lower : Body                                                                                                   : Upper : Active
#            calzini :   1.0 :                x[calzini,bin1] + x[calzini,bin2] + x[calzini,bin3] + x[calzini,bin4] + x[calzini,bin5] :   1.0 :   True
#         fiammiferi :   1.0 : x[fiammiferi,bin1] + x[fiammiferi,bin2] + x[fiammiferi,bin3] + x[fiammiferi,bin4] + x[fiammiferi,bin5] :   1.0 :   True
#            mattone :   1.0 :                x[mattone,bin1] + x[mattone,bin2] + x[mattone,bin3] + x[mattone,bin4] + x[mattone,bin5] :   1.0 :   True
#          pantaloni :   1.0 :      x[pantaloni,bin1] + x[pantaloni,bin2] + x[pantaloni,bin3] + x[pantaloni,bin4] + x[pantaloni,bin5] :   1.0 :   True
#         spazzolino :   1.0 : x[spazzolino,bin1] + x[spazzolino,bin2] + x[spazzolino,bin3] + x[spazzolino,bin4] + x[spazzolino,bin5] :   1.0 :   True
#
# 11 Declarations: x_index_0 x_index_1 x_index x y_index y obj pack_const_index pack_const capacity_const_index capacity_const
